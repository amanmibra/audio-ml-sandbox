# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import librosa
import uuid
from IPython.display import Audio
import librosa
from preprocess import *
from utils import *

DEFAULT_SAMPLE_RATE = 48000

# %%
# torch
import torch
from torch.utils.data import Dataset
import torchaudio

# %%
AMAN_FILE = os.path.join('data', 'aman', os.listdir('data/aman')[0])

# %%
audio, _ = librosa.load(AMAN_FILE, sr=DEFAULT_SAMPLE_RATE)

# %%
audio
# Out:
# array([ 1.3877788e-17, -1.0549546e-04, -4.7564795e-04, ...,
#        -1.7791734e-03, -1.5999315e-03, -1.4841721e-03], dtype=float32)

# %%
Audio(audio, rate=DEFAULT_SAMPLE_RATE)

# %%
display_audio(AMAN_FILE)

# %%
labels = os.listdir('data')
labels

from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit_transform(labels)
# Out:
# array([0, 1, 2])

# %%
"""
from sklearn import preprocessing
import torch

labels = ['cat', 'dog', 'mouse', 'elephant', 'pandas']
le = preprocessing.LabelEncoder()
targets = le.fit_transform(labels)
# targets: array([0, 1, 2, 3, 4])

targets = torch.as_tensor(targets)
# targets: tensor([0, 1, 2, 3, 4])
"""

# %%
print(torch.__version__)
print(torchaudio.__version__)
# Out:
# 2.0.1
# 2.0.2
